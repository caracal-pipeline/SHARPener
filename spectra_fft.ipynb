# %%
##################################################
# #                                              #
##################################################

# import installed python modules
#!/usr/bin/env python

import os, sys, math
import numpy as np

from scipy.fftpack import fft, fftfreq
import apercal

#load magic python notebook module
get_ipython().magic(u'pylab inline')
print 'modules imported'#-------------------------------------------------#
# Out:
# Setup logger with lib.setup_logger()
# Populating the interactive namespace from numpy and matplotlib
# modules imported
# /Users/maccagni/programs/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['fft']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/Obj5/beam_num/abs/spec/'
spec_name = '1_084307+453742'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_spec.txt', delimiter=',', names=True, dtype=None)

freq = np.array(spec_vec['freqHz'],dtype=float)/1e9
flux = np.array(spec_vec['fluxJybeam'],dtype=float)

step = (freq[-1]-freq[0])/len(freq)
yf = fftpack.fft(flux)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center


print 'Termination'
# Out:
# Termination

# %%
f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(freq, flux) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/Obj5/beam_num/abs/spec/'
spec_name = '2_084317+45081'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_spec.txt', delimiter=',', names=True, dtype=None)

freq = np.array(spec_vec['freqHz'],dtype=float)/1e9
flux = np.array(spec_vec['fluxJybeam'],dtype=float)

step = (freq[-1]-freq[0])/len(freq)
print step, freq[-1]
yf = fftpack.fft(flux)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center


print 'Termination'
# Out:
# 3.6934705739227064e-05 1.1979548236517814
# Termination

# %%
f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(freq, flux) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

f.savefig(spec_dir+'nondetection.png')

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/3c293/beam_num/abs/spec/'
spec_name = '23'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_spec.csv', delimiter=',', names=True, dtype=None)

freq = np.array(spec_vec['freqHz'],dtype=float)/1e9
flux = np.array(spec_vec['fluxJybeam'],dtype=float)

step = (freq[-1]-freq[0])/len(freq)
print step, freq[-1]
yf = fftpack.fft(flux)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center
yf = np.absolute(yf)
yf = (yf-np.min(yf))/(np.max(yf)-np.min(yf))
print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(freq, flux) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

f.savefig(spec_dir+'3C293_FULL.png')
# Out:
# -7.770269986702761e-05 1.3519458219923
# Termination

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/3c293/beam_num/abs/spec/'
spec_name = '23'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_resout.csv', delimiter=',', names=True, dtype=None)

#freq = np.array(spec_vec['velo'],dtype=float)
flux = np.array(spec_vec['flux_res'],dtype=float)

step = (freq[-1]-freq[0])/len(freq)
yf = fftpack.fft(flux)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center

yf=np.abs(yf)
yf = (yf-np.min(yf))/(np.max(yf)-np.min(yf))

print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(freq, flux) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

f.savefig(spec_dir+'3C293_RES.png')
# Out:
# Termination

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/3c293/beam_num/abs/spec/'
spec_name = '23'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_resout_sub.csv', delimiter=',', names=True, dtype=None)

#freq = np.array(spec_vec['velo'],dtype=float)
flux = np.array(spec_vec['flux_res'],dtype=float)

noise = np.random.normal(0,2e-3,len(freq))

fluxnoise  = flux + noise

step = (freq[-1]-freq[0])/len(freq)
print step, freq[-1]
yf = fftpack.fft(fluxnoise)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center
yf=np.abs(yf)
yf = (yf-np.min(yf))/(np.max(yf)-np.min(yf))

print 'Termination'


f, ax = plt.subplots(2,2,sharey=False)
ax[0][0].plot(freq, flux) # Plot Cosine terms
ax[0][0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0][0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[0][1].plot(freq, noise) # Plot Sine terms
ax[0][1].set_ylabel(r'noise', size = 'x-large')
ax[0][1].set_xlabel(r'Frequency [Hz]', size = 'x-large')
ax[1][0].plot(freq, fluxnoise) # Plot Sine terms
ax[1][0].set_ylabel(r'noise', size = 'x-large')
ax[1][0].set_xlabel(r'Frequency [Hz]', size = 'x-large')
ax[1][1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1][1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1][1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

f.savefig(spec_dir+'3C293_OUT_noise.png')
# Out:
# -7.770269986702761e-05 1.3519458219923
# Termination

# %%
spec_dir = '/Users/maccagni/Projects/ApertiF/SHARP/data/3c293/beam_num/abs/spec/'
spec_name = '23'

spec_vec = np.genfromtxt(spec_dir+spec_name+'_resout_sub.csv', delimiter=',', names=True, dtype=None)

#freq = np.array(spec_vec['velo'],dtype=float)
flux = np.array(spec_vec['flux_res'],dtype=float)

noise = np.random.normal(0,4.e-3,len(freq))

fluxnoise  = flux + noise

step = (freq[-1]-freq[0])/len(freq)
print step, freq[-1]
yf = fftpack.fft(fluxnoise)
xf = fft.fftfreq(len(freq),step)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center
yf=np.abs(yf)
yf = (yf-np.min(yf))/(np.max(yf)-np.min(yf))

print 'Termination'


f, ax = plt.subplots(2,2,sharey=False)
ax[0][0].plot(freq, flux) # Plot Cosine terms
ax[0][0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0][0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[0][1].plot(freq, noise) # Plot Sine terms
ax[0][1].set_ylabel(r'noise', size = 'x-large')
ax[0][1].set_xlabel(r'Frequency [Hz]', size = 'x-large')
ax[1][0].plot(freq, fluxnoise) # Plot Sine terms
ax[1][0].set_ylabel(r'Flux+noise', size = 'x-large')
ax[1][0].set_xlabel(r'Frequency [Hz]', size = 'x-large')
ax[1][1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1][1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1][1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()

f.savefig(spec_dir+'3C293_OUT_noise.png')
# Out:
# -7.770269986702761e-05 1.3519458219923
# Termination

# %%
#simulate spectrum

import random

x = np.arange(0,1e4,1)
print x
sig=500

noise = np.random.normal(0,1,len(x))

y = np.exp(-np.power(x - 5000, 2.) / (2 * np.power(sig, 2.))) + noise 


yf = fftpack.fft(y)
xf = fft.fftfreq(len(x),25e3)

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center
yf=np.abs(yf)

yf = (yf-np.min(yf))/(np.max(yf)-np.min(yf))


print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(x, y) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
plt.show()
f.savefig(spec_dir+'fakegaussian.png')
# Out:
# [0.000e+00 1.000e+00 2.000e+00 ... 9.997e+03 9.998e+03 9.999e+03]
# Termination

# %%
#simulate spectrum

import random

x = np.arange(0,8e3,1)

sig=100
sig2 = 500
noise = np.random.normal(0,0.05,len(x))

y = np.exp(-np.power(x - 2500, 2.) / (2 * np.power(sig, 2.))) 

y2 = np.exp(-np.power(x - 2800, 2.) / (2 * np.power(sig2, 2.))) / 3


y +=y2

yf = fftpack.fft(y)
xf = fft.fftfreq(len(x))

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center


print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(x, y) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
ax[1].set_xlim([0.,0.01])
plt.show()
# Out:
# Termination

# %%
#simulate spectrum

import random

x = np.arange(0,8e3,1)

sig=100
sig2 = 500
noise = np.random.normal(0,0.05,len(x))

y = np.exp(-np.power(x - 2500, 2.) / (2 * np.power(sig, 2.))) / 4.

y2 = np.exp(-np.power(x - 2800, 2.) / (2 * np.power(sig2, 2.))) / 2.


y +=y2

yf = fftpack.fft(y)
xf = fft.fftfreq(len(x))

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center


print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(x, y) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
ax[1].set_xlim([0.,0.01])
plt.show()
# Out:
# Termination

# %%
#simulate spectrum

import random

x = np.arange(0,8e3,1)

sig=100
sig2 = 500
noise = np.random.normal(0,0.05,len(x))

y = np.exp(-np.power(x - 2500, 2.) / (2 * np.power(sig, 2.))) 

y2 = np.exp(-np.power(x - 2800, 2.) / (2 * np.power(sig2, 2.))) / 2


y +=y2

yf = fftpack.fft(y)
xf = fft.fftfreq(len(x))

yf = fft.fftshift(yf) # Shift zero freq to center
xf = fft.fftshift(xf) # Shift zero freq to center


print 'Termination'


f, ax = plt.subplots(1,2,sharey=False)
ax[0].plot(x, y) # Plot Cosine terms
ax[0].set_ylabel(r'Flux [Jy beam$^{-1}]$', size = 'x-large')
ax[0].set_xlabel(r'Frequency [Hz]', size='x-large')
ax[1].plot(np.absolute(xf), np.absolute(yf)) # Plot Sine terms
ax[1].set_ylabel(r'$\vert F_k \vert ^2$', size = 'x-large')
ax[1].set_xlabel(r'$\widetilde{\nu}$', size = 'x-large')
ax[1].set_xlim([0.,0.01])
plt.show()
# Out:
# Termination
